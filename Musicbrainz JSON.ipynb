# %% [markdown]
# # **JSON practice on musicbrainz.org Web Service**

# %%
import json
import requests

# %%
# Process query to find data about Eminem
BASE_URL = 'https://musicbrainz.org/ws/2/'

# resources on the web service which represent core entities of the database. see link for more details:
# https://musicbrainz.org/doc/MusicBrainz_Entity
entity = 'artist/'
r = requests.get(BASE_URL + 'artist/', params = {'query': 'Eminem', 'fmt': 'json'})

r.json()
# Out:
# {'created': '2020-03-14T23:37:32.123Z',
#  'count': 10,
#  'offset': 0,
#  'artists': [{'id': 'b95ce3ff-3d05-4e87-9e01-c97b66af13d4',
#    'type': 'Person',
#    'type-id': 'b6e035f4-3ce9-331c-97df-83397230b0df',
#    'score': 100,
#    'name': 'Eminem',
#    'sort-name': 'Eminem',
#    'gender': 'male',
#    'area': {'id': 'b03ff310-d8e2-45cf-9455-769f76641eb2',
#     'type': 'City',
#     'type-id': '6fd8f29a-3d0a-32fc-980d-ea697b69da78',
#     'name': 'Detroit',
#     'sort-name': 'Detroit',
#     'life-span': {'ended': None}},
#    'begin-area': {'id': 'bfae8151-2ba2-4f8f-bf2e-8fc16ce352c6',
#     'type': 'City',
#     'type-id': '6fd8f29a-3d0a-32fc-980d-ea697b69da78',
#     'name': 'St. Joseph',
#     'sort-name': 'St. Joseph',
#     'life-span': {'ended': None}},
#    'ipis': ['00354929235', '00354929431'],
#    'isnis': ['0000000117699370', '0000000368611900'],
#    'life-span': {'begin': '1972-10-17', 'ended': None},
#    'aliases': [{'sort-name': 'Ominem',
#      'name': 'Ominem',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Mathers, Marshall B.',
#      'name': 'Marshall B. Mathers',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Mathers, Marshall',
#      'name': 'Marshall Mathers',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'EminemMusic',
#      'type-id': '1937e404-b981-3cb7-8151-4c86ebfc8d8e',
#      'name': 'EminemMusic',
#      'locale': None,
#      'type': 'Search hint',
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Em',
#      'type-id': '894afba6-2816-3c24-8072-eadb66bd04bc',
#      'name': 'Em',
#      'locale': None,
#      'type': 'Artist name',
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Mathers, Marshall Bruce, III',
#      'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf',
#      'name': 'Marshall Bruce Mathers III',
#      'locale': None,
#      'type': 'Legal name',
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Slim Shady',
#      'type-id': '894afba6-2816-3c24-8072-eadb66bd04bc',
#      'name': 'Slim Shady',
#      'locale': None,
#      'type': 'Artist name',
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Mathers, M.',
#      'name': 'M. Mathers',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Eminem',
#      'type-id': '894afba6-2816-3c24-8072-eadb66bd04bc',
#      'name': 'Eminem',
#      'locale': None,
#      'type': 'Artist name',
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Mathers, Marshall B. III',
#      'name': 'Marshall B. Mathers III',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'The Real Slim Shady',
#      'name': 'The Real Slim Shady',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Eminem',
#      'type-id': '894afba6-2816-3c24-8072-eadb66bd04bc',
#      'name': 'Eminem',
#      'locale': 'en',
#      'type': 'Artist name',
#      'primary': True,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'EMINƎM',
#      'type-id': '1937e404-b981-3cb7-8151-4c86ebfc8d8e',
#      'name': 'EMINƎM',
#      'locale': None,
#      'type': 'Search hint',
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'M&M',
#      'type-id': '894afba6-2816-3c24-8072-eadb66bd04bc',
#      'name': 'M&M',
#      'locale': None,
#      'type': 'Artist name',
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Mathers, Marshall Bruce',
#      'name': 'Marshall Bruce Mathers',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None}],
#    'tags': [{'count': -1, 'name': 'turkish'},
#     {'count': 8, 'name': 'rap'},
#     {'count': 1, 'name': 'american'},
#     {'count': 5, 'name': 'hip-hop'},
#     {'count': 18, 'name': 'hip hop'},
#     {'count': 0, 'name': 'hiphop'},
#     {'count': 0, 'name': 'midwest hip-hop'},
#     {'count': 0, 'name': 'detroit hip-hop'},
#     {'count': 0, 'name': 'pop rap'},
#     {'count': 0, 'name': 'horrorcore'},
#     {'count': 0, 'name': 'rapper'},
#     {'count': 0, 'name': 'us'},
#     {'count': 0, 'name': 'pop and chart'},
#     {'count': 0, 'name': 'eminem'},
#     {'count': 0, 'name': '8 mile'},
#     {'count': 0, 'name': 'boom bap'},
#     {'count': 0, 'name': 'v'},
#     {'count': 0, 'name': 'comedy rap'},
#     {'count': 0, 'name': 'hardcore hip hop'}]},
#   {'id': '87f27b14-cbd0-44ea-93a3-6fead5cb45e7',
#    'type': 'Group',
#    'type-id': 'e431f5f6-b5d2-343d-8b36-72607fffb74b',
#    'score': 54,
#    'name': 'Bad Meets Evil',
#    'sort-name': 'Bad Meets Evil',
#    'country': 'US',
#    'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#     'type': 'Country',
#     'type-id': '06dd0ae4-8c74-30bb-b43d-95dcedf961de',
#     'name': 'United States',
#     'sort-name': 'United States',
#     'life-span': {'ended': None}},
#    'begin-area': {'id': 'b03ff310-d8e2-45cf-9455-769f76641eb2',
#     'type': 'City',
#     'type-id': '6fd8f29a-3d0a-32fc-980d-ea697b69da78',
#     'name': 'Detroit',
#     'sort-name': 'Detroit',
#     'life-span': {'ended': None}},
#    'isnis': ['0000000121818248'],
#    'life-span': {'begin': '1997', 'ended': None},
#    'aliases': [{'sort-name': 'Eminem & Royce DA 5-9',
#      'name': 'Eminem & Royce DA 5-9',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Royce da 5\'9" & Eminem',
#      'name': 'Royce da 5\'9" & Eminem',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': "Bad Meets Evil (Eminem & Royce Da 5'9'')",
#      'name': "Bad Meets Evil (Eminem & Royce Da 5'9'')",
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Eminem & Royce DA 59',
#      'name': 'Eminem & Royce DA 59',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Eminem & Royce 5’9',
#      'name': 'Eminem & Royce 5’9',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None},
#     {'sort-name': 'Bad Meets Evil (Eminem and Royce 5-9)',
#      'name': 'Bad Meets Evil (Eminem and Royce 5-9)',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None}],
#    'tags': [{'count': 4, 'name': 'hip hop'},
#     {'count': 1, 'name': 'hardcore hip hop'},
#     {'count': 0, 'name': 'hip-hop'}]},
#   {'id': '70c5b6ed-cea3-4655-97ba-85352e616c2b',
#    'type': 'Person',
#    'type-id': 'b6e035f4-3ce9-331c-97df-83397230b0df',
#    'score': 41,
#    'name': 'Denace',
#    'sort-name': 'Denace',
#    'gender': 'male',
#    'disambiguation': 'Eminem Soundalike',
#    'life-span': {'ended': None}},
#   {'id': 'e2de0653-9ad5-4c2a-a826-aae8413c09cc',
#    'type': 'Person',
#    'type-id': 'b6e035f4-3ce9-331c-97df-83397230b0df',
#    'score': 39,
#    'name': 'Eminemmylou',
#    'sort-name': 'Eminemmylou',
#    'disambiguation': 'Country Rap',
#    'life-span': {'ended': None}},
#   {'id': '2715326b-d158-42f1-b619-61b1fc6463c7',
#    'score': 39,
#    'name': 'Neminem',
#    'sort-name': 'Neminem',
#    'life-span': {'ended': None}},
#   {'id': '2bc08c5e-d78a-434e-ad1f-3d592516b74a',
#    'score': 38,
#    'name': 'Thyme',
#    'sort-name': 'Thyme',
#    'disambiguation': 'Associated with Eminem',
#    'life-span': {'ended': None}},
#   {'id': 'ac5d3a2c-cdcc-4d21-a507-79a7b478fccb',
#    'score': 38,
#    'name': 'Three',
#    'sort-name': 'Three',
#    'disambiguation': 'Associated with Eminem',
#    'life-span': {'ended': None}},
#   {'id': '7dea8be2-c8aa-429c-ab92-9d354d4f08dd',
#    'type': 'Person',
#    'type-id': 'b6e035f4-3ce9-331c-97df-83397230b0df',
#    'score': 37,
#    'name': 'Swift',
#    'sort-name': 'Swift',
#    'gender': 'male',
#    'disambiguation': 'associated with Eminem',
#    'life-span': {'ended': None}},
#   {'id': '5d2ae7a7-9da4-49e0-a27c-717b065d3868',
#    'score': 31,
#    'name': 'Caveman',
#    'sort-name': 'Caveman',
#    'disambiguation': 'Eminem cover of "Real Slim Shady"',
#    'life-span': {'ended': None}},
#   {'id': '5f440044-6d6a-495b-b69a-b2158d2ab172',
#    'type': 'Group',
#    'type-id': 'e431f5f6-b5d2-343d-8b36-72607fffb74b',
#    'score': 27,
#    'name': 'Soul Intent',
#    'sort-name': 'Soul Intent',
#    'country': 'US',
#    'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#     'type': 'Country',
#     'type-id': '06dd0ae4-8c74-30bb-b43d-95dcedf961de',
#     'name': 'United States',
#     'sort-name': 'United States',
#     'life-span': {'ended': None}},
#    'disambiguation': 'short-lived US hip-hop group, key members Eminem and Proof',
#    'life-span': {'ended': None},
#    'aliases': [{'sort-name': 'Bassmint Productions',
#      'name': 'Bassmint Productions',
#      'locale': None,
#      'type': None,
#      'primary': None,
#      'begin-date': None,
#      'end-date': None}]}]}

# %%
# find all of Eminem's aliases
for alias in r.json()['artists'][0]['aliases']:
    print(alias['name'])
# Out:
# Ominem
# Marshall B. Mathers
# Marshall Mathers
# EminemMusic
# Em
# Marshall Bruce Mathers III
# Slim Shady
# M. Mathers
# Eminem
# Marshall B. Mathers III
# The Real Slim Shady
# Eminem
# EMINƎM
# M&M
# Marshall Bruce Mathers

# %%
# get eminem's artist ID on musicbrainz.org
id_ = r.json()['artists'][0]['id']
id_
# Out:
# 'b95ce3ff-3d05-4e87-9e01-c97b66af13d4'

# %%
# use browse request to find out how many unique releases there are in the database
entity = 'release?artist='

r = requests.get(BASE_URL + entity + id_, params={'fmt': 'json'})

# how many releases are included in the database
release_total = r.json()['release-count']

# holds set of unique releases
releases = set()

# keeps track of offset parameter in the query
count = 0

while count < release_total:
    r = requests.get(BASE_URL + entity + id, params={'fmt': 'json', 'limit': 100, 'offset': count})
    count += 100

    # check for duplicates
    for release in r.json()['releases']:
        if release['title'] not in releases:
            releases.add(release['title'])
        
len(releases)
# Out:
# 198

# %%
# print releases
for i in releases:
    print(i)
# Out:
# The Monster
# Straight From the Lab EP
# Guts Over Fear
# Collision Course 3
# Sing for the Moment
# The Story of Marshall Mathers
# Mathers Massacre
# Cleanin’ Out My Closet
# Campaign Speech
# Dreams on Shady Park
# Best of Slim Shady
# All Eyes on Me (The Eminem Files)
# C’Mon Let Me Ride
# After Collision
# The Freestyle Show
# Unmastered Sequence
# The Eminem Show
# Before The Relapse 2
# Kings Never Die
# Straight From the Lab
# Drop the World
# The Freestyle Manual
# Berzerk
# Relapse: Refill
# Remember the Name
# The Eminem Show (Edited Version)
# Off the Wall
# Relapse (Deluxe Version)
# Conscience
# Superman
# I Need a Doctor
# Eminem presented by DJ R Dub L
# America's Nightmare
# Throw That
# Curtain Call: The Hits
# Return of the Psycho
# Quitter / Just Rhymin' With Proof
# Freestyles 2
# Lyrical Invasion
# Wordap.net Presents: The Bassmint Files
# Get the Guns
# Revival
# Freestyles
# Greatest Hits
# E
# Straight from the Lab Part II
# Scary Movies (Stand Well Back radio edit)
# Infinite
# Things Get Worse
# Stan
# Like Toy Soldiers
# Diss Me, Diss You
# Maximum Eminem (The Unauthorised Biography of Eminem)
# I Am Marshall
# Fucking Crazy
# Raw & Uncut
# Detroit King
# The E Tox (A Prelude to Relapse)
# A Beautiful Mind
# The Real Slim Shady
# Without Me
# Role Model / Cum on Everybody / '97 Bonnie & Clyde
# The Underground Collection
# Green Lantern
# The Definitive Collection: Disc 1
# Fight Night
# Piece of Mind
# No Love
# Hellbound
# Survival
# White America
# Chloraseptic (remix)
# The Singles Boxset
# Shady Beats
# Cleanin' Out My Closet
# The Man Not the Myth
# When I'm Gone
# Crack a Bottle
# Unrelease V
# Forever
# Road to Recovery: Withdrawal
# The Setback
# Phenomenal
# Smack That
# Rap God
# Eminem & Friends: Game Over Sessions
# Marshall Carter
# Crank Calls
# Guilty Conscience
# So U Wanna Freestyle?
# Mockingbird
# Straight from the Lab Part I
# Before the Curtain Closes
# Back in the Studio
# 2017-11-18: Saturday Night Live: New York, NY, USA
# Remix Album
# Walk on Water
# Greatest Hits (Chopped & Screwed)
# Killshot
# R.I.P. Kim
# ShadyXV
# Infinite (F.B.T. Remix)
# Platinum Collection 2001
# The Return of Slim Shady
# Live From Comerica Park
# You Don't Know
# Headlights
# Psycho
# Another Set Back
# Straight From the Vault, Volume 1
# Nuttin’ to Do (radio edit)
# The Marshall Mathers LP (Slowed & Chopped)
# The Way I Am
# Hits & Unreleased, Volume 1
# Forever (Tyler Blue Drumstep remix)
# Business
# 8 Mile and Abbey: Eminem Meets the Beatles
# Just Lose It
# Just Finish It
# We Made You
# My Name Is
# Without Me / What You Say
# Marshall and the Soul Brother
# Role Model
# The Shady Project
# It Ain't Over
# Beautiful
# Lost In London
# Music to be Murdered By
# Detroit Chainsaw Massacre
# Maximum Pressure
# Music to Be Murdered By
# The Marshall Mathers LP
# Detox
# Marshall Bruce Mathers III
# MTV Music History
# Shoot to Kill
# Remission
# Unreleased and Rare
# Live at Brixton Academy
# Forgot About Dre
# Kamikaze
# Ready 4 War: Tha Best of Eminem
# Unreleased and Rare (deluxe)
# River
# Unreleased 2
# Better Man
# Unreleased Collection
# More Maximum Eminem (The Unauthorised Biography of Eminem)
# What’s the Difference
# Da King of Da Rap Game?? (Mixed by DJ Jay Faire)
# Venom (Music From The Motion Picture)
# 2000-07-19: Up in Smoke Tour: San Jose, CA, USA
# Shady Situation
# Shake That
# The Slim Shady LP
# Recovery
# Love the Way You Lie
# The Unreleased, Hits & Features
# Double
# My Life
# The Hits & Unreleased, Volume 2
# Encore (Instrumentals)
# Don't Call Me Marshall
# Whiteboy Wasted
# Before the Relapse
# Collision Course II
# Shady Classics
# Recovery: The Mixtape
# Relapse
# Marshall’s Law
# Watch the Throne
# Anger Management 3: The Exclusive Shade 45 Mixtape
# Nowhere Fast (extended version)
# Lose Yourself
# Bottom of the bottle
# Long Time No See
# Who’s the Hottest
# Shady Lane
# Slim Shady EP
# Live In Europe
# Losing It
# 3AM
# Black Amerika
# The Angry Blonde
# The Anger Management Tour Live
# Encore
# The Recovery
# How to Be an MC, Volume 13 (Eminem Instrumentals)
# Live and Fucked Up
# The Marshall Mathers LP 2
# DJ Hero Renegade Edition
# Not Afraid
# Ass Like That
# Eminem Is Back
# Renegades
# Just Don't Give a Fuck
# Drama Setter

# %%
# use another browse query to find out how many unique tracks there are in the database
entity = 'recording?artist='

r = requests.get(BASE_URL + entity + id_, params={'fmt': 'json'})
r.json()
# Out:
# {'recording-count': 3179,
#  'recordings': [{'title': "(God Is) Cleanin' Out My Closet",
#    'id': '06562717-5266-464a-b69a-79051af8c2f1',
#    'video': False,
#    'length': 385000,
#    'disambiguation': ''},
#   {'video': False,
#    'disambiguation': '',
#    'length': 47306,
#    'title': "'Entertainment'(interlude)",
#    'id': '09713d9a-dfe4-4c8b-a70e-055d1731ec00'},
#   {'id': '24a4a114-d8bd-4b36-8b51-51e94e73b780',
#    'title': '’Till I Collapse',
#    'length': 297907,
#    'disambiguation': 'clean',
#    'video': False},
#   {'id': '2e8677c2-bbd6-429c-97ec-6a3ac736d733',
#    'title': "'Retarded Kid' Freestyle",
#    'length': 53093,
#    'disambiguation': '',
#    'video': False},
#   {'title': '[unknown]',
#    'id': '45396c00-1e18-4cfd-b722-225421e6e8fb',
#    'video': False,
#    'disambiguation': '',
#    'length': 6334},
#   {'title': '’Till I Collapse',
#    'id': '58ba910b-4762-4c76-99bf-02031e11dd94',
#    'video': False,
#    'length': 297893,
#    'disambiguation': 'explicit'},
#   {'length': 271000,
#    'disambiguation': '',
#    'video': False,
#    'id': '5b053b5f-99d9-4184-b898-25942434e390',
#    'title': "'97 Bonnie & Clyde (club edit)"},
#   {'length': 36826,
#    'disambiguation': '',
#    'video': False,
#    'id': '719c31d8-09d9-4b63-be9c-92a1244a131a',
#    'title': "'Hailey'(interlude)"},
#   {'title': "'Till I Collapse / Cinderella Man",
#    'id': '7b3345c7-8cd4-403b-ba28-fe5243f485bb',
#    'video': False,
#    'disambiguation': '',
#    'length': 318000},
#   {'title': "'Dick Disappear' Freestyle",
#    'id': '7df69ad6-9204-4e53-a983-4f1adad598db',
#    'video': False,
#    'length': 52933,
#    'disambiguation': ''},
#   {'disambiguation': '',
#    'length': 206000,
#    'video': False,
#    'id': '80fbfcba-89a1-45be-8b0f-8d6042706a93',
#    'title': '[freestyle]'},
#   {'title': '’Till I Collapse / Nowhere Man',
#    'id': '9e99df83-8fdd-4e1a-a736-8b03b7781d18',
#    'video': False,
#    'disambiguation': '',
#    'length': 207830},
#   {'title': "'97 Bonnie & Clyde",
#    'id': 'a140b3f9-fc63-4410-a27c-849d5c18783d',
#    'video': False,
#    'length': 317880,
#    'disambiguation': ''},
#   {'id': 'abcc5e2f-a6c8-4948-9024-dd35d2fcfe5c',
#    'title': "'Bleep Bleep' Freestyle",
#    'length': 49346,
#    'disambiguation': '',
#    'video': False},
#   {'video': False,
#    'length': 249000,
#    'disambiguation': '',
#    'title': '’Till I Collapse (Scenario)',
#    'id': 'af55867a-05d8-4ee7-b94c-34dc39eab387'},
#   {'disambiguation': '',
#    'length': 30000,
#    'video': False,
#    'id': 'd01e1496-8cd9-40a6-9f07-b3733be05266',
#    'title': '[PA track: Lose Yourself]'},
#   {'video': False,
#    'disambiguation': '',
#    'length': 60413,
#    'title': "'Psycho' Freestyle",
#    'id': 'd02dbeae-6a83-46de-a4c0-e95005387f82'},
#   {'length': 289280,
#    'disambiguation': '',
#    'video': False,
#    'id': 'd60eb973-a5cf-4511-8876-ccaff469e35c',
#    'title': '[unknown]'},
#   {'video': False,
#    'disambiguation': 'clean',
#    'length': 316000,
#    'title': '’97 Bonnie & Clyde',
#    'id': 'da9f6925-84b8-4048-ada3-47ea30851397'},
#   {'title': "'New Language' Freestyle",
#    'id': 'dabafeb3-871e-4e3a-ac49-fb91d8a3b83a',
#    'video': False,
#    'length': 70120,
#    'disambiguation': ''},
#   {'video': False,
#    'disambiguation': '',
#    'length': 252000,
#    'title': "'97 Rap Olympics",
#    'id': 'dd802e22-69f5-4b03-9841-2b55c394b17f'},
#   {'length': 82546,
#    'disambiguation': '',
#    'video': False,
#    'id': 'e014c87c-99ec-45ce-a75f-63cb602a4b3e',
#    'title': '(interlude)'},
#   {'video': False,
#    'disambiguation': '',
#    'length': 16773,
#    'title': "'Respect' Break",
#    'id': 'f1d74533-f1b8-499e-b75f-d179e0a9c29b'},
#   {'video': False,
#    'length': 48880,
#    'disambiguation': '',
#    'title': "'2 Faced' A Cappella Freestyle",
#    'id': 'f3dcc7e7-aff7-4efa-851c-836449827590'},
#   {'id': 'f597a2dd-0b9c-46d9-bc67-bbd48a6532a7',
#    'title': "'Pick It Up' Freestyle",
#    'disambiguation': '',
#    'length': 82920,
#    'video': False}],
#  'recording-offset': 0}

# %%
recordings_total = r.json()['recording-count']
recordings_total
# Out:
# 3179

# %%
# need time.sleep to avoid exceeding musicbrainz's 50 requests per second limit
import time

# keeps track of offset parameter
count = 0

# holds set of unique releases
recordings = set()

while count < recordings_total:
    
    r = requests.get(BASE_URL + entity + id_, params={'fmt': 'json', 'limit': 100, 'offset': count})
    count += 100
    
    # check recording is not a music video clip and check for duplicates
    for i in r.json()['recordings']:
        if not i['video'] and i['title'] not in recordings:
            recordings.add(i['title'])
    
    # wait 1 sec
    time.sleep(1)
                
len(recordings)
# Out:
# 1964
